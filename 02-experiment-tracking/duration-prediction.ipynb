# %%
# !python -V
# Out:
# Python 3.9.19

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp-mausul/02-experiment-tracking/mlruns/1', creation_time=1716274678962, experiment_id='1', last_update_time=1716274678962, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# !ls
# Out:
# data			   mlflow-exploration.ipynb  mlruns  requirements.txt
# duration-prediction.ipynb  mlflow.db		     models

# %%
numerical = ['trip_distance']

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df['duration'] = df['duration'].apply(lambda td: td.total_seconds() / 60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
df_val['PU_DO'].head()
# Out:
# 0    130_205
# 1    152_244
# 2     152_48
# 3    152_241
# 4      75_42
# Name: PU_DO, dtype: object

# %%
categorical = ['PU_DO']  # ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.758715208009878

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "Abu Tyeb Azad Mausul")
    
    mlflow.log_param("train_data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("val-data-path", "./data/green_tripdata_2021-02.parquet")
    
    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    
    lr = Lasso(alpha=alpha)
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    with open('models/lin_reg.bin', 'wb') as f_out:
        pickle.dump((dv, lr), f_out)
    
    # FAQ: The ending slash of 'artifact_path' creates problems (mlflow treats the path as file instead of folder)
    mlflow.log_artifact(local_path='models/lin_reg.bin', artifact_path='models_pickle')
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %% [markdown]
# **Flow for using hyperopt: define a objective function --> specify search_space dict --> pass params to fmin**

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # range: log(uniform_dist([exp(-3), exp(0)]))
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42,
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)

# %%
# Use the hyperparams from best(?) run for training
params = {
    'learning_rate': 0.0786595878556475,
    'max_depth': 51,
    'min_child_weight': 1.9905475557209629,
    'objective': 'reg:linear',
    'reg_alpha': 0.04386766359221766,
    'reg_lambda': 0.0047249573930281084,
    'seed': 42
}

# %%
# autolog
mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=1000,
    evals=[(valid, "validation")],
    early_stopping_rounds=50
)
y_pred = booster.predict(valid)
rmse = mean_squared_error(y_val, y_pred, squared=False)

# %% [markdown]
# Logging model as artifact is not good for using the model for prediction on new data in production

# %%
# Model Logging: Approach 2 (Approach 1: using log_artifact method)
with mlflow.start_run():
    best_params = {
        'learning_rate': 0.0786595878556475,
        'max_depth': 51,
        'min_child_weight': 1.9905475557209629,
        'objective': 'reg:linear',
        'reg_alpha': 0.04386766359221766,
        'reg_lambda': 0.0047249573930281084,
        'seed': 42
    }

    mlflow.log_params(best_params)
    
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, "validation")],
        early_stopping_rounds=50
    )
    
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric('rmse', rmse)

    # Store the dict vectorizer (will be needed for preprocessing new data (features) in production before prediciting
    with open('models/preprocessor.b', 'wb') as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact(local_path='models/preprocessor.b', artifact_path='preprocessor')
    
    mlflow.xgboost.log_model(booster, artifact_path='models_mlflow')
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [05:22:22] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.57458
# [1]	validation-rmse:11.00100
# [2]	validation-rmse:10.48709
# [3]	validation-rmse:10.02694
# [4]	validation-rmse:9.61584
# [5]	validation-rmse:9.24921
# [6]	validation-rmse:8.92285
# [7]	validation-rmse:8.63461
# [8]	validation-rmse:8.37978
# [9]	validation-rmse:8.15610
# [10]	validation-rmse:7.95759
# [11]	validation-rmse:7.78402
# [12]	validation-rmse:7.63205
# [13]	validation-rmse:7.49670
# [14]	validation-rmse:7.37852
# [15]	validation-rmse:7.27310
# [16]	validation-rmse:7.18303
# [17]	validation-rmse:7.10275
# [18]	validation-rmse:7.03238
# [19]	validation-rmse:6.97067
# [20]	validation-rmse:6.91515
# [21]	validation-rmse:6.86822
# [22]	validation-rmse:6.82645
# [23]	validation-rmse:6.78886
# [24]	validation-rmse:6.75543
# [25]	validation-rmse:6.72604
# [26]	validation-rmse:6.70012
# [27]	validation-rmse:6.67683
# [28]	validation-rmse:6.65645
# [29]	validation-rmse:6.63746
# [30]	validation-rmse:6.62088
# [31]	validation-rmse:6.60632
# [32]	validation-rmse:6.59244
# [33]	validation-rmse:6.58073
# [34]	validation-rmse:6.56886
# [35]	validation-rmse:6.55881
# [36]	validation-rmse:6.54887
# [37]	validation-rmse:6.54040
# [38]	validation-rmse:6.53328
# [39]	validation-rmse:6.52572
# [40]	validation-rmse:6.51964
# [41]	validation-rmse:6.51371
# [42]	validation-rmse:6.50838
# [43]	validation-rmse:6.50340
# [44]	validation-rmse:6.49939
# [45]	validation-rmse:6.49495
# [46]	validation-rmse:6.49082
# [47]	validation-rmse:6.48707
# [48]	validation-rmse:6.48326
# [49]	validation-rmse:6.48003
# [50]	validation-rmse:6.47709
# [51]	validation-rmse:6.47374
# [52]	validation-rmse:6.47101
# [53]	validation-rmse:6.46880
# [54]	validation-rmse:6.46710
# [55]	validation-rmse:6.46521
# [56]	validation-rmse:6.46391
# [57]	validation-rmse:6.46262
# [58]	validation-rmse:6.46170
# [59]	validation-rmse:6.46016
# [60]	validation-rmse:6.45918
# [61]	validation-rmse:6.45802
# [62]	validation-rmse:6.45723
# [63]	validation-rmse:6.45601
# [64]	validation-rmse:6.45541
# [65]	validation-rmse:6.45504
# [66]	validation-rmse:6.45435
# [67]	validation-rmse:6.45375
# [68]	validation-rmse:6.45262
# [69]	validation-rmse:6.45162
# [70]	validation-rmse:6.45075
# [71]	validation-rmse:6.45026
# [72]	validation-rmse:6.44946
# [73]	validation-rmse:6.44860
# [74]	validation-rmse:6.44772
# [75]	validation-rmse:6.44663
# [76]	validation-rmse:6.44589
# [77]	validation-rmse:6.44482
# [78]	validation-rmse:6.44428
# [79]	validation-rmse:6.44342
# [80]	validation-rmse:6.44247
# [81]	validation-rmse:6.44177
# [82]	validation-rmse:6.44099
# [83]	validation-rmse:6.44031
# [84]	validation-rmse:6.43965
# [85]	validation-rmse:6.43914
# [86]	validation-rmse:6.43845
# [87]	validation-rmse:6.43774
# [88]	validation-rmse:6.43729
# [89]	validation-rmse:6.43618
# [90]	validation-rmse:6.43534
# [91]	validation-rmse:6.43489
# [92]	validation-rmse:6.43419
# [93]	validation-rmse:6.43352
# [94]	validation-rmse:6.43298
# [95]	validation-rmse:6.43228
# [96]	validation-rmse:6.43145
# [97]	validation-rmse:6.43049
# [98]	validation-rmse:6.42990
# [99]	validation-rmse:6.42945
# [100]	validation-rmse:6.42895
# [101]	validation-rmse:6.42838
# [102]	validation-rmse:6.42773
# [103]	validation-rmse:6.42717
# [104]	validation-rmse:6.42661
# [105]	validation-rmse:6.42604
# [106]	validation-rmse:6.42544
# [107]	validation-rmse:6.42450
# [108]	validation-rmse:6.42391
# [109]	validation-rmse:6.42313
# [110]	validation-rmse:6.42263
# [111]	validation-rmse:6.42227
# [112]	validation-rmse:6.42143
# [113]	validation-rmse:6.42095
# [114]	validation-rmse:6.42042
# [115]	validation-rmse:6.41992
# [116]	validation-rmse:6.41952
# [117]	validation-rmse:6.41868
# [118]	validation-rmse:6.41795
# [119]	validation-rmse:6.41730
# [120]	validation-rmse:6.41688
# [121]	validation-rmse:6.41640
# [122]	validation-rmse:6.41606
# [123]	validation-rmse:6.41554
# [124]	validation-rmse:6.41511
# [125]	validation-rmse:6.41473
# [126]	validation-rmse:6.41432
# [127]	validation-rmse:6.41405
# [128]	validation-rmse:6.41342
# [129]	validation-rmse:6.41310
# [130]	validation-rmse:6.41261
# [131]	validation-rmse:6.41221
# [132]	validation-rmse:6.41128
# [133]	validation-rmse:6.41085
# [134]	validation-rmse:6.41031
# [135]	validation-rmse:6.40988
# [136]	validation-rmse:6.40935
# [137]	validation-rmse:6.40902
# [138]	validation-rmse:6.40860
# [139]	validation-rmse:6.40780
# [140]	validation-rmse:6.40765
# [141]	validation-rmse:6.40734
# [142]	validation-rmse:6.40679
# [143]	validation-rmse:6.40628
# [144]	validation-rmse:6.40578
# [145]	validation-rmse:6.40523
# [146]	validation-rmse:6.40467
# [147]	validation-rmse:6.40426
# [148]	validation-rmse:6.40389
# [149]	validation-rmse:6.40338
# [150]	validation-rmse:6.40307
# [151]	validation-rmse:6.40278
# [152]	validation-rmse:6.40254
# [153]	validation-rmse:6.40204
# [154]	validation-rmse:6.40171
# [155]	validation-rmse:6.40137
# [156]	validation-rmse:6.40073
# [157]	validation-rmse:6.40048
# [158]	validation-rmse:6.40012
# [159]	validation-rmse:6.39992
# [160]	validation-rmse:6.39924
# [161]	validation-rmse:6.39871
# [162]	validation-rmse:6.39814
# [163]	validation-rmse:6.39781
# [164]	validation-rmse:6.39749
# [165]	validation-rmse:6.39698
# [166]	validation-rmse:6.39651
# [167]	validation-rmse:6.39611
# [168]	validation-rmse:6.39584
# [169]	validation-rmse:6.39535
# [170]	validation-rmse:6.39499
# [171]	validation-rmse:6.39448
# [172]	validation-rmse:6.39409
# [173]	validation-rmse:6.39393
# [174]	validation-rmse:6.39349
# [175]	validation-rmse:6.39297
# [176]	validation-rmse:6.39262
# [177]	validation-rmse:6.39223
# [178]	validation-rmse:6.39189
# [179]	validation-rmse:6.39150
# [180]	validation-rmse:6.39118
# [181]	validation-rmse:6.39086
# [182]	validation-rmse:6.39065
# [183]	validation-rmse:6.39028
# [184]	validation-rmse:6.39001
# [185]	validation-rmse:6.38978
# [186]	validation-rmse:6.38947
# [187]	validation-rmse:6.38913
# [188]	validation-rmse:6.38891
# [189]	validation-rmse:6.38833
# [190]	validation-rmse:6.38818
# [191]	validation-rmse:6.38784
# [192]	validation-rmse:6.38763
# [193]	validation-rmse:6.38742
# [194]	validation-rmse:6.38724
# [195]	validation-rmse:6.38677
# [196]	validation-rmse:6.38612
# [197]	validation-rmse:6.38566
# [198]	validation-rmse:6.38538
# [380]	validation-rmse:6.34745
# [381]	validation-rmse:6.34730
# [382]	validation-rmse:6.34733
# [383]	validation-rmse:6.34714
# [384]	validation-rmse:6.34686
# [385]	validation-rmse:6.34675
# [386]	validation-rmse:6.34665
# [387]	validation-rmse:6.34646
# [388]	validation-rmse:6.34642
# [389]	validation-rmse:6.34639
# [390]	validation-rmse:6.34621
# [391]	validation-rmse:6.34600
# [392]	validation-rmse:6.34603
# [393]	validation-rmse:6.34595
# [394]	validation-rmse:6.34582
# [395]	validation-rmse:6.34566
# [396]	validation-rmse:6.34557
# [397]	validation-rmse:6.34532
# [398]	validation-rmse:6.34519
# [399]	validation-rmse:6.34505
# [400]	validation-rmse:6.34498
# [401]	validation-rmse:6.34471
# [402]	validation-rmse:6.34448
# [403]	validation-rmse:6.34427
# [404]	validation-rmse:6.34425
# [405]	validation-rmse:6.34415
# [406]	validation-rmse:6.34389
# [407]	validation-rmse:6.34373
# [408]	validation-rmse:6.34366
# [409]	validation-rmse:6.34358
# [410]	validation-rmse:6.34337
# [411]	validation-rmse:6.34317
# [412]	validation-rmse:6.34309
# [413]	validation-rmse:6.34301
# [414]	validation-rmse:6.34289
# [415]	validation-rmse:6.34277
# [416]	validation-rmse:6.34249
# [417]	validation-rmse:6.34233
# [418]	validation-rmse:6.34218
# [419]	validation-rmse:6.34213
# [420]	validation-rmse:6.34200
# [421]	validation-rmse:6.34196
# [422]	validation-rmse:6.34176
# [423]	validation-rmse:6.34157
# [424]	validation-rmse:6.34149
# [425]	validation-rmse:6.34141
# [426]	validation-rmse:6.34108
# [427]	validation-rmse:6.34092
# [428]	validation-rmse:6.34084
# [429]	validation-rmse:6.34076
# [430]	validation-rmse:6.34071
# [431]	validation-rmse:6.34057
# [432]	validation-rmse:6.34054
# [433]	validation-rmse:6.34052
# [434]	validation-rmse:6.34049
# [435]	validation-rmse:6.34030
# [436]	validation-rmse:6.34021
# [437]	validation-rmse:6.34018
# [438]	validation-rmse:6.34006
# [439]	validation-rmse:6.33991
# [440]	validation-rmse:6.33954
# [441]	validation-rmse:6.33956
# [442]	validation-rmse:6.33943
# [443]	validation-rmse:6.33933
# [444]	validation-rmse:6.33922
# [445]	validation-rmse:6.33915
# [446]	validation-rmse:6.33906
# [447]	validation-rmse:6.33885
# [448]	validation-rmse:6.33879
# [449]	validation-rmse:6.33873
# [450]	validation-rmse:6.33855
# [451]	validation-rmse:6.33848
# [452]	validation-rmse:6.33829
# [453]	validation-rmse:6.33819
# [454]	validation-rmse:6.33816
# [455]	validation-rmse:6.33818
# [456]	validation-rmse:6.33816
# [457]	validation-rmse:6.33803
# [458]	validation-rmse:6.33811
# [459]	validation-rmse:6.33798
# [460]	validation-rmse:6.33788
# [461]	validation-rmse:6.33771
# [462]	validation-rmse:6.33756
# [463]	validation-rmse:6.33761
# [464]	validation-rmse:6.33737
# [465]	validation-rmse:6.33722
# [466]	validation-rmse:6.33707
# [467]	validation-rmse:6.33669
# [468]	validation-rmse:6.33667
# [469]	validation-rmse:6.33648
# [470]	validation-rmse:6.33646
# [471]	validation-rmse:6.33641
# [472]	validation-rmse:6.33634
# [473]	validation-rmse:6.33630
# [474]	validation-rmse:6.33607
# [475]	validation-rmse:6.33599
# [476]	validation-rmse:6.33588
# [477]	validation-rmse:6.33580
# [478]	validation-rmse:6.33581
# [479]	validation-rmse:6.33558
# [480]	validation-rmse:6.33541
# [481]	validation-rmse:6.33526
# [482]	validation-rmse:6.33525
# [483]	validation-rmse:6.33515
# [484]	validation-rmse:6.33513
# [485]	validation-rmse:6.33500
# [486]	validation-rmse:6.33483
# [487]	validation-rmse:6.33471
# [488]	validation-rmse:6.33449
# [489]	validation-rmse:6.33391
# [490]	validation-rmse:6.33389
# [491]	validation-rmse:6.33382
# [492]	validation-rmse:6.33372
# [493]	validation-rmse:6.33368
# [494]	validation-rmse:6.33361
# [495]	validation-rmse:6.33350
# [496]	validation-rmse:6.33330
# [497]	validation-rmse:6.33318
# [498]	validation-rmse:6.33320
# [499]	validation-rmse:6.33311
# [500]	validation-rmse:6.33278
# [501]	validation-rmse:6.33238
# [502]	validation-rmse:6.33226
# [503]	validation-rmse:6.33210
# [504]	validation-rmse:6.33195
# [505]	validation-rmse:6.33188
# [506]	validation-rmse:6.33187
# [507]	validation-rmse:6.33173
# [508]	validation-rmse:6.33176
# [509]	validation-rmse:6.33177
# [510]	validation-rmse:6.33162
# [511]	validation-rmse:6.33154
# [512]	validation-rmse:6.33155
# [513]	validation-rmse:6.33132
# [514]	validation-rmse:6.33122
# [515]	validation-rmse:6.33118
# [516]	validation-rmse:6.33110
# [517]	validation-rmse:6.33111
# [518]	validation-rmse:6.33118
# [519]	validation-rmse:6.33106
# [520]	validation-rmse:6.33101
# [521]	validation-rmse:6.33095
# [522]	validation-rmse:6.33075
# [523]	validation-rmse:6.33073
# [524]	validation-rmse:6.33066
# [525]	validation-rmse:6.33049
# [526]	validation-rmse:6.33013
# [527]	validation-rmse:6.33001
# [528]	validation-rmse:6.32994
# [529]	validation-rmse:6.32993
# [530]	validation-rmse:6.32978
# [531]	validation-rmse:6.32977
# [532]	validation-rmse:6.32978
# [533]	validation-rmse:6.32979
# [534]	validation-rmse:6.32966
# [535]	validation-rmse:6.32976
# [536]	validation-rmse:6.32929
# [537]	validation-rmse:6.32948
# [538]	validation-rmse:6.32942
# [539]	validation-rmse:6.32936
# [540]	validation-rmse:6.32928
# [541]	validation-rmse:6.32906
# [542]	validation-rmse:6.32898
# [543]	validation-rmse:6.32890
# [544]	validation-rmse:6.32893
# [545]	validation-rmse:6.32888
# [546]	validation-rmse:6.32870
# [547]	validation-rmse:6.32871
# [548]	validation-rmse:6.32863
# [549]	validation-rmse:6.32844
# [550]	validation-rmse:6.32835
# [551]	validation-rmse:6.32827
# [552]	validation-rmse:6.32821
# [553]	validation-rmse:6.32809
# [554]	validation-rmse:6.32795
# [555]	validation-rmse:6.32795
# [556]	validation-rmse:6.32788
# [557]	validation-rmse:6.32787
# [558]	validation-rmse:6.32773
# [559]	validation-rmse:6.32758
# [560]	validation-rmse:6.32750
# [561]	validation-rmse:6.32731
# [562]	validation-rmse:6.32738
# [563]	validation-rmse:6.32737
# [564]	validation-rmse:6.32732
# [565]	validation-rmse:6.32724
# [566]	validation-rmse:6.32708
# [567]	validation-rmse:6.32687
# [568]	validation-rmse:6.32678
# [569]	validation-rmse:6.32680
# [570]	validation-rmse:6.32664
# [571]	validation-rmse:6.32655
# [572]	validation-rmse:6.32649
# [573]	validation-rmse:6.32645
# [574]	validation-rmse:6.32585
# [575]	validation-rmse:6.32571
# [576]	validation-rmse:6.32568
# [577]	validation-rmse:6.32560
# [578]	validation-rmse:6.32563
# [579]	validation-rmse:6.32552
# [580]	validation-rmse:6.32544
# [581]	validation-rmse:6.32532
# [582]	validation-rmse:6.32525
# [583]	validation-rmse:6.32519
# [584]	validation-rmse:6.32506
# [585]	validation-rmse:6.32508
# [586]	validation-rmse:6.32478
# [587]	validation-rmse:6.32462
# [588]	validation-rmse:6.32460
# [589]	validation-rmse:6.32458
# [590]	validation-rmse:6.32451
# [591]	validation-rmse:6.32435
# [592]	validation-rmse:6.32418
# [593]	validation-rmse:6.32412
# [594]	validation-rmse:6.32414
# [595]	validation-rmse:6.32391
# [596]	validation-rmse:6.32388
# [597]	validation-rmse:6.32381
# [598]	validation-rmse:6.32374
# [599]	validation-rmse:6.32373
# [600]	validation-rmse:6.32371
# [601]	validation-rmse:6.32362
# [602]	validation-rmse:6.32361
# [603]	validation-rmse:6.32351
# [604]	validation-rmse:6.32342
# [605]	validation-rmse:6.32330
# [606]	validation-rmse:6.32331
# [607]	validation-rmse:6.32318
# [608]	validation-rmse:6.32322
# [609]	validation-rmse:6.32299
# [610]	validation-rmse:6.32296
# [611]	validation-rmse:6.32291
# [612]	validation-rmse:6.32277
# [613]	validation-rmse:6.32269
# [614]	validation-rmse:6.32266
# [615]	validation-rmse:6.32231
# [616]	validation-rmse:6.32225
# [617]	validation-rmse:6.32223
# [618]	validation-rmse:6.32219
# [619]	validation-rmse:6.32224
# [620]	validation-rmse:6.32219
# [621]	validation-rmse:6.32199
# [622]	validation-rmse:6.32181
# [623]	validation-rmse:6.32176
# [624]	validation-rmse:6.32169
# [625]	validation-rmse:6.32160
# [626]	validation-rmse:6.32159
# [627]	validation-rmse:6.32158
# [628]	validation-rmse:6.32167
# [629]	validation-rmse:6.32163
# [630]	validation-rmse:6.32172
# [631]	validation-rmse:6.32172
# [632]	validation-rmse:6.32160
# [633]	validation-rmse:6.32146
# [634]	validation-rmse:6.32129
# [635]	validation-rmse:6.32102
# [636]	validation-rmse:6.32085
# [637]	validation-rmse:6.32091
# [638]	validation-rmse:6.32093
# [639]	validation-rmse:6.32084
# [640]	validation-rmse:6.32063
# [641]	validation-rmse:6.32062
# [642]	validation-rmse:6.32059
# [643]	validation-rmse:6.32008
# [644]	validation-rmse:6.32016
# [645]	validation-rmse:6.31994
# [646]	validation-rmse:6.32000
# [647]	validation-rmse:6.32005
# [648]	validation-rmse:6.31997
# [649]	validation-rmse:6.31988
# [650]	validation-rmse:6.31984
# [741]	validation-rmse:6.31520
# [742]	validation-rmse:6.31509
# [743]	validation-rmse:6.31512
# [744]	validation-rmse:6.31521
# [745]	validation-rmse:6.31509
# [746]	validation-rmse:6.31504
# [747]	validation-rmse:6.31485
# [748]	validation-rmse:6.31471
# [749]	validation-rmse:6.31467
# [750]	validation-rmse:6.31458
# [751]	validation-rmse:6.31454
# [752]	validation-rmse:6.31443
# [753]	validation-rmse:6.31442
# [754]	validation-rmse:6.31445
# [755]	validation-rmse:6.31442
# [756]	validation-rmse:6.31421
# [757]	validation-rmse:6.31429
# [758]	validation-rmse:6.31431
# [759]	validation-rmse:6.31440
# [760]	validation-rmse:6.31436
# [761]	validation-rmse:6.31437
# [762]	validation-rmse:6.31433
# [763]	validation-rmse:6.31430
# [764]	validation-rmse:6.31434
# [765]	validation-rmse:6.31419
# [766]	validation-rmse:6.31419
# [767]	validation-rmse:6.31406
# [768]	validation-rmse:6.31395
# [769]	validation-rmse:6.31402
# [770]	validation-rmse:6.31411
# [771]	validation-rmse:6.31406
# [772]	validation-rmse:6.31399
# [773]	validation-rmse:6.31404
# [774]	validation-rmse:6.31409
# [775]	validation-rmse:6.31394
# [776]	validation-rmse:6.31393
# [777]	validation-rmse:6.31395
# [778]	validation-rmse:6.31391
# [779]	validation-rmse:6.31383
# [780]	validation-rmse:6.31383
# [781]	validation-rmse:6.31374
# [782]	validation-rmse:6.31364
# [783]	validation-rmse:6.31362
# [784]	validation-rmse:6.31362
# [785]	validation-rmse:6.31354
# [786]	validation-rmse:6.31348
# [787]	validation-rmse:6.31345
# [788]	validation-rmse:6.31342
# [789]	validation-rmse:6.31344
# [790]	validation-rmse:6.31343
# [791]	validation-rmse:6.31346
# [792]	validation-rmse:6.31336
# [793]	validation-rmse:6.31330
# [794]	validation-rmse:6.31335
# [795]	validation-rmse:6.31331
# [796]	validation-rmse:6.31342
# [797]	validation-rmse:6.31343
# [798]	validation-rmse:6.31342
# [799]	validation-rmse:6.31348
# [800]	validation-rmse:6.31340
# [801]	validation-rmse:6.31342
# [802]	validation-rmse:6.31339
# [803]	validation-rmse:6.31344
# [804]	validation-rmse:6.31328
# [805]	validation-rmse:6.31329
# [806]	validation-rmse:6.31324
# [807]	validation-rmse:6.31312
# [808]	validation-rmse:6.31310
# [809]	validation-rmse:6.31315
# [810]	validation-rmse:6.31320
# [811]	validation-rmse:6.31318
# [812]	validation-rmse:6.31321
# [813]	validation-rmse:6.31302
# [814]	validation-rmse:6.31287
# [815]	validation-rmse:6.31285
# [816]	validation-rmse:6.31284
# [817]	validation-rmse:6.31292
# [818]	validation-rmse:6.31292
# [819]	validation-rmse:6.31288
# [820]	validation-rmse:6.31289
# [821]	validation-rmse:6.31282
# [822]	validation-rmse:6.31284
# [823]	validation-rmse:6.31284
# [824]	validation-rmse:6.31271
# [825]	validation-rmse:6.31275
# [826]	validation-rmse:6.31304
# [827]	validation-rmse:6.31303
# [828]	validation-rmse:6.31296
# [829]	validation-rmse:6.31286
# [830]	validation-rmse:6.31295
# [831]	validation-rmse:6.31298
# [832]	validation-rmse:6.31289
# [833]	validation-rmse:6.31289
# [834]	validation-rmse:6.31285
# [835]	validation-rmse:6.31280
# [836]	validation-rmse:6.31277
# [837]	validation-rmse:6.31275
# [838]	validation-rmse:6.31258
# [839]	validation-rmse:6.31267
# [840]	validation-rmse:6.31279
# [841]	validation-rmse:6.31273
# [842]	validation-rmse:6.31308
# [843]	validation-rmse:6.31308
# [844]	validation-rmse:6.31307
# [845]	validation-rmse:6.31307
# [846]	validation-rmse:6.31293
# [847]	validation-rmse:6.31309
# [848]	validation-rmse:6.31303
# [849]	validation-rmse:6.31295
# [850]	validation-rmse:6.31288
# [851]	validation-rmse:6.31291
# [852]	validation-rmse:6.31287
# [853]	validation-rmse:6.31285
# [854]	validation-rmse:6.31293
# [855]	validation-rmse:6.31285
# [856]	validation-rmse:6.31303
# [857]	validation-rmse:6.31304
# [858]	validation-rmse:6.31304
# [859]	validation-rmse:6.31295
# [860]	validation-rmse:6.31293
# [861]	validation-rmse:6.31290
# [862]	validation-rmse:6.31284
# [863]	validation-rmse:6.31277
# [864]	validation-rmse:6.31279
# [865]	validation-rmse:6.31280
# [866]	validation-rmse:6.31273
# [867]	validation-rmse:6.31274
# [868]	validation-rmse:6.31274
# [869]	validation-rmse:6.31259
# [870]	validation-rmse:6.31258
# [871]	validation-rmse:6.31253
# [872]	validation-rmse:6.31259
# [873]	validation-rmse:6.31259
# [874]	validation-rmse:6.31254
# [875]	validation-rmse:6.31249
# [876]	validation-rmse:6.31246
# [877]	validation-rmse:6.31237
# [878]	validation-rmse:6.31224
# [879]	validation-rmse:6.31233
# [880]	validation-rmse:6.31210
# [881]	validation-rmse:6.31196
# [882]	validation-rmse:6.31179
# [883]	validation-rmse:6.31185
# [884]	validation-rmse:6.31178
# [885]	validation-rmse:6.31182
# [886]	validation-rmse:6.31180
# [887]	validation-rmse:6.31179
# [888]	validation-rmse:6.31164
# [889]	validation-rmse:6.31165
# [890]	validation-rmse:6.31155
# [891]	validation-rmse:6.31157
# [892]	validation-rmse:6.31162
# [893]	validation-rmse:6.31153
# [894]	validation-rmse:6.31156
# [895]	validation-rmse:6.31156
# [896]	validation-rmse:6.31156
# [897]	validation-rmse:6.31168
# [898]	validation-rmse:6.31163
# [899]	validation-rmse:6.31154
# [900]	validation-rmse:6.31152
# [901]	validation-rmse:6.31160
# [902]	validation-rmse:6.31146
# [903]	validation-rmse:6.31151
# [904]	validation-rmse:6.31145
# [905]	validation-rmse:6.31159
# [906]	validation-rmse:6.31155
# [907]	validation-rmse:6.31149
# [908]	validation-rmse:6.31148
# [909]	validation-rmse:6.31144
# [910]	validation-rmse:6.31136
# [911]	validation-rmse:6.31140
# [912]	validation-rmse:6.31143
# [913]	validation-rmse:6.31148
# [914]	validation-rmse:6.31158
# [915]	validation-rmse:6.31149
# [916]	validation-rmse:6.31148
# [917]	validation-rmse:6.31147
# [918]	validation-rmse:6.31142
# [919]	validation-rmse:6.31144
# [920]	validation-rmse:6.31141
# [921]	validation-rmse:6.31148
# [922]	validation-rmse:6.31151
# [923]	validation-rmse:6.31146
# [924]	validation-rmse:6.31153
# [925]	validation-rmse:6.31142
# [926]	validation-rmse:6.31161
# [927]	validation-rmse:6.31155
# [928]	validation-rmse:6.31153
# [929]	validation-rmse:6.31152
# [930]	validation-rmse:6.31150
# [931]	validation-rmse:6.31150
# [932]	validation-rmse:6.31147
# [933]	validation-rmse:6.31146
# [934]	validation-rmse:6.31140
# [935]	validation-rmse:6.31133
# [936]	validation-rmse:6.31127
# [937]	validation-rmse:6.31110
# [938]	validation-rmse:6.31112
# [939]	validation-rmse:6.31114
# [940]	validation-rmse:6.31127
# [941]	validation-rmse:6.31145
# [942]	validation-rmse:6.31164
# [943]	validation-rmse:6.31156
# [944]	validation-rmse:6.31183
# [945]	validation-rmse:6.31175
# [946]	validation-rmse:6.31160
# [947]	validation-rmse:6.31148
# [948]	validation-rmse:6.31150
# [949]	validation-rmse:6.31142
# [950]	validation-rmse:6.31137
# [951]	validation-rmse:6.31137
# [952]	validation-rmse:6.31133
# [953]	validation-rmse:6.31130
# [954]	validation-rmse:6.31125
# [955]	validation-rmse:6.31130
# [956]	validation-rmse:6.31120
# [957]	validation-rmse:6.31113
# [958]	validation-rmse:6.31107
# [959]	validation-rmse:6.31101
# [960]	validation-rmse:6.31096
# [961]	validation-rmse:6.31095
# [962]	validation-rmse:6.31101
# [963]	validation-rmse:6.31120
# [964]	validation-rmse:6.31120
# [965]	validation-rmse:6.31115
# [966]	validation-rmse:6.31116
# [967]	validation-rmse:6.31109
# [968]	validation-rmse:6.31101
# [969]	validation-rmse:6.31106
# [970]	validation-rmse:6.31106
# [971]	validation-rmse:6.31109
# [972]	validation-rmse:6.31113
# [973]	validation-rmse:6.31118
# [974]	validation-rmse:6.31123
# [975]	validation-rmse:6.31119
# [976]	validation-rmse:6.31117
# [977]	validation-rmse:6.31114
# [978]	validation-rmse:6.31112
# [979]	validation-rmse:6.31108
# [980]	validation-rmse:6.31103
# [981]	validation-rmse:6.31099
# [982]	validation-rmse:6.31103
# [983]	validation-rmse:6.31102
# [984]	validation-rmse:6.31094
# [985]	validation-rmse:6.31115
# [986]	validation-rmse:6.31118
# [987]	validation-rmse:6.31120
# [988]	validation-rmse:6.31114
# [989]	validation-rmse:6.31112
# [990]	validation-rmse:6.31111
# [991]	validation-rmse:6.31109
# [992]	validation-rmse:6.31103
# [993]	validation-rmse:6.31095
# [994]	validation-rmse:6.31092
# [995]	validation-rmse:6.31093
# [996]	validation-rmse:6.31100
# [997]	validation-rmse:6.31097
# [998]	validation-rmse:6.31106
# [999]	validation-rmse:6.31112
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [05:27:35] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
# use logged model (from mlflow) for prediction
logged_model = 'runs:/15b97c40d9b1416e8168aab8c633f166/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [05:32:16] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 15b97c40d9b1416e8168aab8c633f166

# %%
# use logged model as xgboost/other flavor model
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [05:35:19] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:10]
# Out:
# array([14.291193 ,  6.9891047, 15.000826 , 24.387764 ,  9.480561 ,
#        17.16951  , 10.7379   ,  8.236133 ,  9.214026 , 20.105375 ],
#       dtype=float32)
